# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset # To write NetCDF files
import dask
from dask.distributed import Client, LocalCluster

# %%
cluster = LocalCluster(n_workers=10,memory_limit="100GiB")  # Launches a scheduler and workers locally
client = Client(cluster)

# %%
# %%time
path ="/glade/campaign/acom/acom-climate/nadavis/WACCM/FWmaHIST_ne30pg3_ne30pg3_mg17_no_conus_gravity_waves/atm/hist/"
ds_nonrr = xr.open_mfdataset(path + "*h1*2010-01-*")
ds_nonrr
# Out:
# CPU times: user 3.33 s, sys: 1.56 s, total: 4.9 s
# Wall time: 6.88 s
# <xarray.Dataset>
# Dimensions:       (lat: 257, lon: 512, time: 31, lev: 110, ilev: 111, nbnd: 2)
# Coordinates:
#   * lat           (lat) float64 -90.0 -89.3 -88.59 -87.89 ... 88.59 89.3 90.0
#   * lon           (lon) float64 0.0 0.7031 1.406 2.109 ... 357.9 358.6 359.3
#   * lev           (lev) float64 6.14e-06 9.453e-06 1.455e-05 ... 976.3 992.6
#   * ilev          (ilev) float64 4.949e-06 7.618e-06 1.173e-05 ... 985.1 1e+03
#   * time          (time) object 2010-01-01 00:00:00 ... 2010-01-31 00:00:00
# Dimensions without coordinates: nbnd
# Data variables: (12/92)
#     w             (time, lat) float64 dask.array<chunksize=(1, 257), meta=np.ndarray>
#     hyam          (time, lev) float64 dask.array<chunksize=(1, 110), meta=np.ndarray>
#     hybm          (time, lev) float64 dask.array<chunksize=(1, 110), meta=np.ndarray>
# ...

# %%
# %%time
path ="/glade/campaign/acom/acom-climate/nadavis/WACCM/FWmaHIST_ne0CONUSne30x8_ne0CONUSne30x8_mt12_no_conus_gravity_waves/atm/hist/"
ds_rr = xr.open_mfdataset(path+"*h1*2010-01*")
ds_rr
# Out:
# CPU times: user 1.99 s, sys: 2.5 s, total: 4.49 s
# Wall time: 6.06 s
# <xarray.Dataset>
# Dimensions:       (lat: 769, lon: 1536, time: 31, lev: 110, ilev: 111, nbnd: 2)
# Coordinates:
#   * lat           (lat) float64 -90.0 -89.77 -89.53 -89.3 ... 89.53 89.77 90.0
#   * lon           (lon) float64 0.0 0.2344 0.4687 0.7031 ... 359.3 359.5 359.8
#   * lev           (lev) float64 6.14e-06 9.453e-06 1.455e-05 ... 976.3 992.6
#   * ilev          (ilev) float64 4.949e-06 7.618e-06 1.173e-05 ... 985.1 1e+03
#   * time          (time) object 2010-01-01 00:00:00 ... 2010-01-31 00:00:00
# Dimensions without coordinates: nbnd
# Data variables: (12/92)
#     w             (time, lat) float64 dask.array<chunksize=(1, 769), meta=np.ndarray>
#     hyam          (time, lev) float64 dask.array<chunksize=(1, 110), meta=np.ndarray>
#     hybm          (time, lev) float64 dask.array<chunksize=(1, 110), meta=np.ndarray>
# ...

# %%
cluster = LocalCluster(n_workers=10,memory_limit="100GiB")  # Launches a scheduler and workers locally
client = Client(cluster)

# %%
ds_nonrr.T
# Out:
# <xarray.DataArray 'T' (time: 31, lev: 110, lat: 257, lon: 512)>
# dask.array<concatenate, shape=(31, 110, 257, 512), dtype=float32, chunksize=(1, 110, 257, 512), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.3 -88.59 -87.89 ... 87.89 88.59 89.3 90.0
#   * lon      (lon) float64 0.0 0.7031 1.406 2.109 ... 357.2 357.9 358.6 359.3
#   * lev      (lev) float64 6.14e-06 9.453e-06 1.455e-05 ... 957.5 976.3 992.6
#   * time     (time) object 2010-01-01 00:00:00 ... 2010-01-31 00:00:00
# Attributes:
#     mdims:         1
#     units:         K
#     long_name:     Temperature
#     cell_methods:  time: mean

# %%
# %%time
var = 'T'

# Extract data for Non-RR
ds_nonrr_var = ds_nonrr[var].sel(lon=slice(210,310))

# Extract data for RR and interpolate to lat lon grid of Non-RR
lon_vals = ds_nonrr.lon.values 
lat_vals = ds_nonrr.lat.values
ds_rr_var = ds_rr[var].interp(lon=lon_vals,lat=lat_vals).sel(lon=slice(210,310)) 

# Perform operation 
ds_nonrr_var = ds_nonrr_var.mean(dim=("lon","time")).compute()
ds_rr_var = ds_rr_var.mean(dim=("lon","time")).compute()
# Out:
# CPU times: user 8.08 s, sys: 1.69 s, total: 9.77 s
# Wall time: 1min 22s
